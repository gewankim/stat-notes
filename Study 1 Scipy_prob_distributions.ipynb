# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
#diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)
#data = datasets.load_breast_cancer()
#print(data.DESCR)
#print(data.data)
#print(data.target)
#print(type(data.target)) #type() checks data type in python
#print(data.keys())
#print(data.DESCR)
#print(data.feature_names) #here feature_names should have have () because it is not a function to call
#print(data.target_names)
#import pandas as pd
#df=pd.DataFrame(data.data, columns=data.feature_names)
#df.head()
#df['Target']=data.target
#print(df.info())
#print(f"sum of target is {df['Target'].sum()}")
#print(f"mean of target is {df['Target'].mean()}")
#df1=df.loc[0:3,['mean radius','mean texture']]
#print(df1)
#print("\n")
#print(f"Variance of \n {df1.var()}")
#df.to_csv('breast_cancer')\print("\n")
#print("\n")
#print(df.describe())
#a = np.array([[10, 7, 4], [3, 2, 1]])
#print(a)
#print("median of a is {}".format(np.quantile(a, 0.5)))
#print("median of a by column is {}".format(np.quantile(a, 0.5, axis=0)))
#print("median of a by row is {}".format(np.quantile(a, 0.5, axis=1)))
from scipy.stats import norm
print(norm.rvs(0,1,10))
print(norm.pdf(np.arange(-5,5,1),0,2))
print(norm.cdf(0,0,1))
print(norm.ppf(np.arange(.9,1,.01),0,1)) #ppf finds percentiles of N(0,1).
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1) #reference: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html
x = np.linspace(norm.ppf(0.01), norm.ppf(0.99), 100)
print(type(x))
print(x)
ax.plot(x, norm.pdf(x), 'b-', lw=1, alpha=1, label='norm pdf')
ax.plot(x, norm.pdf(x), 'k-', lw=2, label='frozen pdf')
ax.plot(x, norm.cdf(x), 'k-', lw=2, label='frozen cdf')

r = norm.rvs(266,16,size=10000)
print(type(r)) #this shows r is a narray
ax.hist(r, density=True, bins='auto', histtype='stepfilled', alpha=1)
ax.set_xlim([x[0], x[-1]]) ### ???
ax.legend(loc='best', frameon=False)
plt.show()
norm.stats(266,2,"mvsk") #mean, variance, skew, kurtosis
norm.pdf(0,0,1)
norm.cdf(0,0,1)
norm.fit(r) #parameter estimates based on the data r

#The following is a recursion - calling a function within itself
def recur_factorial(n):
   """Function to return the factorial of a number using recursion"""
   if n == 1:
      return n
   else:
      return n*recur_factorial(n-1)
recur_factorial(4)
# Out:
# [ 0.6683299   1.42115291 -1.56844188 -0.88654573  0.54130331 -0.08366121
#   0.86574145  0.81863389 -1.87982889 -0.01012977]
# [0.00876415 0.02699548 0.0647588  0.12098536 0.17603266 0.19947114
#  0.17603266 0.12098536 0.0647588  0.02699548]
# 0.5
# [1.28155157 1.34075503 1.40507156 1.47579103 1.55477359 1.64485363
#  1.75068607 1.88079361 2.05374891 2.32634787]
# <class 'numpy.ndarray'>
# [-2.32634787 -2.27935095 -2.23235402 -2.18535709 -2.13836017 -2.09136324
#  -2.04436631 -1.99736939 -1.95037246 -1.90337553 -1.85637861 -1.80938168
#  -1.76238475 -1.71538783 -1.6683909  -1.62139397 -1.57439705 -1.52740012
#  -1.48040319 -1.43340627 -1.38640934 -1.33941241 -1.29241549 -1.24541856
#  -1.19842163 -1.15142471 -1.10442778 -1.05743085 -1.01043393 -0.963437
#  -0.91644007 -0.86944314 -0.82244622 -0.77544929 -0.72845236 -0.68145544
#  -0.63445851 -0.58746158 -0.54046466 -0.49346773 -0.4464708  -0.39947388
#  -0.35247695 -0.30548002 -0.2584831  -0.21148617 -0.16448924 -0.11749232
# ...
